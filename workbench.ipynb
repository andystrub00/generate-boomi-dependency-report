# %% [markdown]
# # Imports

# %%
import os
import json

import requests
import pandas as pd

from typing import Optional
from dotenv import load_dotenv

# %% [markdown]
# # Parse JSON

# %%
with open("dev/logging/final_component_store.json") as infile:
    raw_data = json.load(infile)

# %%
for i in raw_data:
    if len(i['parentComponentIds']) > 0 or len(i['childComponentIds']) > 0:
        if i.get('name') is not None:
            
            print(f"{i.get('name')}: parents-{i.get('parentComponentIds')}, children-{i.get('childComponentIds')}")
        else:
            print(f"{i.get('componentId')}: parents-{i.get('parentComponentIds')}, children-{i.get('childComponentIds')}")
# Out:
# [TEMP] [sub] Sub Process One: parents-['e9b2bfa0-9607-4fb5-8ebe-10379a752034'], children-['a07be6ce-13b6-41e1-a983-f7f78503bc20', '04b0cc6d-2a36-44a5-8d0f-c8ccf255caf4', 'fb128b14-fcbb-4a3b-a9d7-c466c11cd518']
# [TEMP] [Main] Parent Process Two: parents-[], children-['a07be6ce-13b6-41e1-a983-f7f78503bc20', 'fb128b14-fcbb-4a3b-a9d7-c466c11cd518']
# map_in_main_folder: parents-[], children-['0e095a54-0662-49ec-b06a-b46dabaad63f', 'a12fc257-f4be-403a-adbc-5eb4f5505978', '6eb35b33-1db1-4d82-a9b1-3a4feaca210d']
# [TEMP] Database V2 Operation: parents-['3a8fa0b3-0641-4ecb-aad7-085951ba59df', '26b680b8-4e09-4fd7-8143-872f4eb46e47'], children-[]
# [TEMP] [Main] Parent Process One: parents-[], children-['26b680b8-4e09-4fd7-8143-872f4eb46e47', '1d51728d-1417-4e19-a510-71681ee7c3b2']
# [TEMP] Database V2 Connection: parents-['3a8fa0b3-0641-4ecb-aad7-085951ba59df', '26b680b8-4e09-4fd7-8143-872f4eb46e47'], children-[]
# Component Reference Testing Map: parents-['e3e4fc78-21bd-49ac-91f3-eaf06d011254', '26b680b8-4e09-4fd7-8143-872f4eb46e47'], children-['f3f22476-431b-4e86-a690-fddf33781686']
# json_profile_in_sub_folder: parents-['5d117b3f-240d-4ba5-8a01-b421b5974158'], children-[]
# component reference testing flat file: parents-['04b0cc6d-2a36-44a5-8d0f-c8ccf255caf4'], children-[]
# e3e4fc78-21bd-49ac-91f3-eaf06d011254: parents-[], children-['04b0cc6d-2a36-44a5-8d0f-c8ccf255caf4']
# 6eb35b33-1db1-4d82-a9b1-3a4feaca210d: parents-['5d117b3f-240d-4ba5-8a01-b421b5974158'], children-[]
# a12fc257-f4be-403a-adbc-5eb4f5505978: parents-['5d117b3f-240d-4ba5-8a01-b421b5974158'], children-[]
# 1d51728d-1417-4e19-a510-71681ee7c3b2: parents-['e9b2bfa0-9607-4fb5-8ebe-10379a752034'], children-[]

# %%
for i in raw_data:
    if len(i['parentComponentIds']) > 0 or len(i['childComponentIds']) > 0:
        if i.get('name') is not None:
            
            print(f"{i.get('name')}: parents-{i.get('parentComponentIds')}, children-{i.get('childComponentIds')}")
        else:
            print(f"{i.get('componentId')}: parents-{i.get('parentComponentIds')}, children-{i.get('childComponentIds')}")
# Out:
# [TEMP] [sub] Sub Process One: parents-['e9b2bfa0-9607-4fb5-8ebe-10379a752034'], children-['fb128b14-fcbb-4a3b-a9d7-c466c11cd518', 'a07be6ce-13b6-41e1-a983-f7f78503bc20', '04b0cc6d-2a36-44a5-8d0f-c8ccf255caf4']
# [TEMP] [Main] Parent Process Two: parents-[], children-['fb128b14-fcbb-4a3b-a9d7-c466c11cd518', 'a07be6ce-13b6-41e1-a983-f7f78503bc20']
# [TEMP] Database V2 Operation: parents-['26b680b8-4e09-4fd7-8143-872f4eb46e47', '3a8fa0b3-0641-4ecb-aad7-085951ba59df'], children-[]
# [TEMP] [Main] Parent Process One: parents-[], children-['26b680b8-4e09-4fd7-8143-872f4eb46e47', '1d51728d-1417-4e19-a510-71681ee7c3b2']
# [TEMP] Database V2 Connection: parents-['26b680b8-4e09-4fd7-8143-872f4eb46e47', '3a8fa0b3-0641-4ecb-aad7-085951ba59df'], children-[]
# Component Reference Testing Map: parents-['26b680b8-4e09-4fd7-8143-872f4eb46e47', 'e3e4fc78-21bd-49ac-91f3-eaf06d011254'], children-['f3f22476-431b-4e86-a690-fddf33781686']
# json_profile_in_sub_folder: parents-['5d117b3f-240d-4ba5-8a01-b421b5974158'], children-[]
# component reference testing flat file: parents-['04b0cc6d-2a36-44a5-8d0f-c8ccf255caf4'], children-[]
# e3e4fc78-21bd-49ac-91f3-eaf06d011254: parents-[], children-['04b0cc6d-2a36-44a5-8d0f-c8ccf255caf4']
# 5d117b3f-240d-4ba5-8a01-b421b5974158: parents-[], children-['0e095a54-0662-49ec-b06a-b46dabaad63f']
# 1d51728d-1417-4e19-a510-71681ee7c3b2: parents-['e9b2bfa0-9607-4fb5-8ebe-10379a752034'], children-[]

# %%
for i in raw_data:
    if len(i['parentComponentIds']) > 0 or len(i['childComponentIds']) > 0:
        if i.get('name') is not None:
            
            print(f"{i.get('name')}: parents-{i.get('parentComponentIds')}, children-{i.get('childComponentIds')}")
        else:
            print(f"{i.get('componentId')}: parents-{i.get('parentComponentIds')}, children-{i.get('childComponentIds')}")
# Out:
# [TEMP] [sub] Sub Process One: parents-['e9b2bfa0-9607-4fb5-8ebe-10379a752034'], children-['fb128b14-fcbb-4a3b-a9d7-c466c11cd518', 'a07be6ce-13b6-41e1-a983-f7f78503bc20', '04b0cc6d-2a36-44a5-8d0f-c8ccf255caf4']
# [TEMP] [Main] Parent Process Two: parents-[], children-['fb128b14-fcbb-4a3b-a9d7-c466c11cd518', 'a07be6ce-13b6-41e1-a983-f7f78503bc20']
# [TEMP] Database V2 Operation: parents-['26b680b8-4e09-4fd7-8143-872f4eb46e47', '3a8fa0b3-0641-4ecb-aad7-085951ba59df'], children-[]
# [TEMP] [Main] Parent Process One: parents-[], children-['26b680b8-4e09-4fd7-8143-872f4eb46e47', '1d51728d-1417-4e19-a510-71681ee7c3b2']
# [TEMP] Database V2 Connection: parents-['26b680b8-4e09-4fd7-8143-872f4eb46e47', '3a8fa0b3-0641-4ecb-aad7-085951ba59df'], children-[]
# Component Reference Testing Map: parents-['e3e4fc78-21bd-49ac-91f3-eaf06d011254', '26b680b8-4e09-4fd7-8143-872f4eb46e47'], children-['f3f22476-431b-4e86-a690-fddf33781686']
# json_profile_in_sub_folder: parents-['5d117b3f-240d-4ba5-8a01-b421b5974158'], children-[]
# component reference testing flat file: parents-['04b0cc6d-2a36-44a5-8d0f-c8ccf255caf4'], children-[]
# 5d117b3f-240d-4ba5-8a01-b421b5974158: parents-[], children-['0e095a54-0662-49ec-b06a-b46dabaad63f']
# e3e4fc78-21bd-49ac-91f3-eaf06d011254: parents-[], children-['04b0cc6d-2a36-44a5-8d0f-c8ccf255caf4']
# 1d51728d-1417-4e19-a510-71681ee7c3b2: parents-['e9b2bfa0-9607-4fb5-8ebe-10379a752034'], children-[]

# %%
# Access environment variables
ACCOUNT_ID = os.getenv("ACCOUNT_ID")
BOOMI_USER = os.getenv("BOOMI_USER")
ACCESS_TOKEN = os.getenv("ACCESS_TOKEN")

print(ACCOUNT_ID)
print(BOOMI_USER)
print(ACCESS_TOKEN)
# Out:
# personal-K8JJK1
# andy.strubhar@argano.com
# 14592d8f-25a0-4d20-97e5-a0a7e17eb49f

# %% [markdown]
# # Build Bulk GET Request

# %%
with open("get_component_ref_response.json") as f:
    data = json.load(f)

# %%
new_query = []
for i in data['response']:
    for j in i['Result']['references']:
        new_query.extend([j['parentComponentId'], j['componentId']])

new_query = list(set(new_query))


new_query = [{"id": i} for i in new_query]

query_body = {"type":"GET", "request":new_query}

# %%
def write_to_debug_log(
    message: str,
    debug_log_path: str = "logging",
    debug_log_filename: str = "debug_log",
    debug_log_suffix: str = ".txt",
):
    '''
    Writes a debug message to a log file.
    Parameters
    ----------
    message : str
        The debug message to be written to the log file.
    debug_log_path : str, optional
        The relative path to the directory where the log file will be stored (default is "logging").
    debug_log_filename : str, optional
        The name of the log file without the suffix (default is "debug_log").
    debug_log_suffix : str, optional
        The suffix of the log file (default is ".txt").
    Returns
    -------
    None
    '''

    # Get the directory where the current script is located
    script_dir = os.path.dirname(os.path.abspath(__file__))

    # Get the parent directory of the script
    parent_dir = os.path.dirname(script_dir)

    # Construct the path to the logging folder
    logging_folder = os.path.join(parent_dir, debug_log_path)

    # Check if the folder exists
    if os.path.isdir(logging_folder):

        with open(
            f"{os.path.join(debug_log_path,debug_log_filename)}{debug_log_suffix}", "w"
        ) as f:
            f.write(f"{message}")

        print(
            f"Debug log written to {os.path.join(debug_log_path,debug_log_filename)}{debug_log_suffix}."
        )

    else:
        print(f"Error: {logging_folder} does not exist.")
        print("Debug log not written.")

# %%
len(generate_json_requests(new_query)[-1]['request'])
# Out:
# 48

# %%
len(generate_json_requests(new_query))
# Out:
# 6

# %%
print(json.dumps(query_body))
# Out:
# {"type": "GET", "request": [{"id": "1c76a5f4-e1d0-4980-9c6f-4f04aabc7733"}, {"id": "6d6259e2-74d4-4510-948f-71575f8dcc31"}, {"id": "5ea93bdb-d13d-4209-868a-d21debe61362"}, {"id": "d3b39045-1d11-448c-87f7-d7e787a7c574"}, {"id": "6165a1b3-704d-442c-8752-1017c9a10742"}, {"id": "91d72778-81ec-4ac0-98e2-cc7a99593c4b"}, {"id": "befc5147-d32e-46c5-a976-8620caa50cd2"}, {"id": "d9b1bf00-9b7c-4c2e-a06c-6c773382df00"}, {"id": "be3360f5-6657-4e26-9c97-caf88a6e2841"}, {"id": "ee1b0088-5d2f-4830-be28-dd197d57e6e0"}, {"id": "08067b65-bc76-4c61-bd2d-1f86adee8c6d"}, {"id": "9d0cb4f1-52a7-4a15-aafe-686e9240c399"}, {"id": "178af759-8503-474e-ae4b-df1eddd418ca"}, {"id": "ec686899-2fc3-4f4c-a1d9-85151c5d3d4f"}, {"id": "1efca273-f5b5-4817-a2f7-f66f0356b8f4"}, {"id": "25c6fc38-e3dc-45de-ac79-046a39a73859"}, {"id": "185e80b5-7b3b-4a91-a45c-4841a23c8fbc"}, {"id": "f1140bc8-d3f6-4b06-a7c0-092e3b935f39"}, {"id": "090cb580-b0c5-4af0-a3d2-dd7c70c96b2e"}, {"id": "4cba6cb4-0ace-45a5-a993-27629cf83072"}, {"id": "b25d889d-322d-4388-a612-c0c474fba59b"}, {"id": "79d63f44-4e48-4a8b-9312-cd283e65fc69"}, {"id": "bf5fdb04-5717-412c-8f08-c356713bdef9"}, {"id": "1ac9f2ad-ba51-4c2d-a791-fa1a704dde02"}, {"id": "9090f329-819e-4c58-b7b8-ee03bd488a69"}, {"id": "ccc40148-796f-44ee-b4ef-059b9e7e372f"}, {"id": "6e15db94-61d2-4df9-b9b4-5df8b470b52c"}, {"id": "32c4dfaa-2328-4c85-9b4a-c63dfda43e44"}, {"id": "4bb5e550-ef8e-47df-a1a5-e8adedccf6d1"}, {"id": "74663b45-ccc1-45f4-bb46-41409aef29bd"}, {"id": "4942d511-c1cc-4a01-b3af-bd8c61dcd111"}, {"id": "43db6c64-a6ad-4b2d-8814-8e533c9fa50b"}, {"id": "3b3dd044-4725-46be-9ebc-311bd8a9e409"}, {"id": "822ecd9f-8b76-4243-ac46-9b1341a03fdd"}, {"id": "f1d8988e-c119-4505-afc4-be74ea2d897a"}, {"id": "e7139a0a-d0d5-4501-9a40-a6f9541a8335"}, {"id": "b35143de-d151-4222-ae9e-88bd06b42e79"}, {"id": "b534ada2-ec21-4e77-8b91-147827846443"}, {"id": "16ea5d09-a34e-4141-b3df-489ea0da3d5b"}, {"id": "9985569c-27d8-4359-9078-1fb7fca75090"}, {"id": "8b5f224e-bb0c-4d85-a1df-b0527dc95296"}, {"id": "dacb53c5-e3fe-4535-8289-f41709257137"}, {"id": "85471635-b0e7-49de-af64-bed374b0227c"}, {"id": "582898a0-03ca-4892-8d32-a939deb1e548"}, {"id": "6e2eddb9-7045-4064-8c4d-f577d5b1c295"}, {"id": "49767a55-29cc-4d70-93e5-0b3b0c53e370"}, {"id": "e8a47778-66aa-4746-aa2b-23bdaab83857"}, {"id": "fee6f0cd-51db-4ed3-b1ba-dfa1f6fdcb1a"}, {"id": "2c53b1ed-c445-4175-ba14-1494097af693"}, {"id": "94ca7b78-816c-4764-b979-fb4a78e9edcb"}, {"id": "c447db66-8ac4-4552-90f1-5a12a183ed33"}, {"id": "c0c2b908-0bb1-4b5f-8289-ea30b3f772bd"}, {"id": "c3e3229c-40c6-45b9-861f-196b126351bc"}, {"id": "fa545ea0-fc3f-44a6-a539-a57f8124bfd6"}, {"id": "9f7f2e40-d56a-4d9e-a905-af2836c84cc8"}, {"id": "663cbaa4-4f2b-46d3-8207-4a1af9f16756"}, {"id": "d4b00a91-9504-4073-9b8a-61e0bdcecdc5"}, {"id": "f0af27e1-6c2b-4aba-b9d0-ae36fd1e906a"}, {"id": "d52f4f3c-4b28-4020-a05b-3dbf1e6183da"}, {"id": "244fd14d-0eb2-495d-b444-a4e744e54ab8"}, {"id": "265baccf-07ce-40ab-9552-043cc24f8b34"}, {"id": "4fbbae4f-369f-4057-8f85-fdb3f0678e9b"}, {"id": "8ebc7bad-24cb-4817-81a4-ba1b67a4ff09"}, {"id": "6b523f2b-f106-4ec0-a124-7c01a1145b1d"}, {"id": "594e424d-5d77-40c2-999c-a9f4a3acd9eb"}, {"id": "7b2011ec-b125-47f9-881b-4245780c2cf0"}, {"id": "2a04bd67-fd75-459e-aea5-966d2096f891"}, {"id": "94fdcf3d-6cbb-4829-b895-7c76fec92dac"}, {"id": "9fbbcacd-80d8-433b-a587-965b19cf71ba"}, {"id": "b36fda30-badf-4a7b-860d-6ed34c32988c"}, {"id": "3b19af81-03c5-449a-8b72-231992849064"}, {"id": "5011b957-3125-42d8-b6ef-6f35310b1eb1"}, {"id": "414ccda2-2689-4c7d-a57f-6b87ed0ba314"}, {"id": "b92188fd-8aab-4c0c-a637-93161cb3ddb7"}, {"id": "9f73b85c-8ad8-4cd8-afb6-8511434a462d"}, {"id": "f041956f-60cf-4943-b5d2-815dbd50aca1"}, {"id": "28abf7d8-0418-4613-a2d6-61a03182aca6"}, {"id": "bcf6e9a2-d006-4db0-a2bb-16047f884ad5"}, {"id": "6b1b9d46-6f9b-43c9-a272-db7827b5b124"}, {"id": "a25aa91e-4acc-4fa9-a463-7826e364e8ba"}, {"id": "9938f9d2-8868-487f-a461-f13b5e316c49"}, {"id": "35d8b92d-6e2e-4756-9a3c-0fa856497663"}, {"id": "a7b98ca6-6319-4d47-9afb-0e41 ...

# %%
len(list(set(new_query)))

# %% [markdown]
# # Set Default Headers and Auth

# %%
account_id = "personal-K8JJK1"
base_url = f"https://api.boomi.com/api/rest/v1/{account_id}"

default_headers = {
    "Content-Type": "application/json",
    "Accept":"application/json",
    "user":"BOOMI_TOKEN.andy.strubhar@argano.com:14592d8f-25a0-4d20-97e5-a0a7e17eb49f",
    "Connection": "close"
    }

# %% [markdown]
# # Function Declerations

# %% [markdown]
# ## Get Env Vars - getEnvironmentVariables

# %%
def getEnvironmentVariables() -> dict:
    '''
    Gets environment variables from a .env file in the same directory as the script containing this function

    Returns
    -------
    dict
        A dictionary of environment vars, with the following form
            {
            "ACCOUNT_ID": ACCOUNT_ID,
            "BOOMI_USER": BOOMI_USER,
            "ACCESS_TOKEN": ACCESS_TOKEN,
            "API_USERNAME":"BOOMI_TOKEN.<BOOMI_USER>"
            }
    '''

    from dotenv import load_dotenv
    load_dotenv()

    # Access environment variables
    ACCOUNT_ID = os.getenv("ACCOUNT_ID")
    BOOMI_USER = os.getenv("BOOMI_USER")
    ACCESS_TOKEN = os.getenv("ACCESS_TOKEN")

    credentials = {
        "ACCOUNT_ID": ACCOUNT_ID,
        "BOOMI_USER": BOOMI_USER,
        "ACCESS_TOKEN": ACCESS_TOKEN,
        "API_USERNAME":f"BOOMI_TOKEN.{BOOMI_USER}"
        }

    return credentials

# %% [markdown]
# ## Build Headers Object - buildHeadersObject

# %%
def buildHeadersObject(api_credentials: dict, custom_args: Optional[dict] = None) -> dict:
    '''
    Builds a default dictionary of HTTP Headers with the following values:

        Content-Type: application/json
        Accept: application/json
        Connection: close
        user: <user authentication string> (Built from .env variables)

    If the custom_args dictionary is included, any key: value pairs in the dict will be added to the default headers.
    If any of the above keys are included in custom_args, the user provided value will overwrite the defualt value.

    Parameters
    ----------
    api_credentials : dict
        Dictonary of Environment Variables
    custom_args : dict, optional
        Dictionary of custom key:value pairs to include in the header dict, by default None

    Returns
    -------
    dict
        The dictionary to be used as json headers for an HTTP request 
    '''

    
    if custom_args is None:
        custom_args = {}


    default_headers = {
    "Content-Type": "application/json",
    "Accept":"application/json",
    "user":f"BOOMI_TOKEN.{api_credentials['BOOMI_USER']}:{api_credentials['ACCESS_TOKEN']}",
    "Connection": "close"
    }

    for custom_key, custom_value in custom_args.items():
        default_headers[custom_key] = custom_value


    return default_headers

# %% [markdown]
# ## Make Standard POST Request - postRequestJSON

# %%
def postRequestJSON(resource_path: str, request_body: str, custom_headers: Optional[dict] = None) -> requests.models.Response:
    '''
    Makes a standard POST request with JSON body

    Parameters
    ----------
    resource_path : str
        resouce path to append to the base url
    request_body : str
        stringified JSON request body
    custom_headers : Optional[dict], optional
        custom header values to add to default headers, by default None

    Returns
    -------
    requests.models.Response
        HTTP Response
    '''

    api_credentials = getEnvironmentVariables()
    
    if resource_path.startswith("/"):
        resource_path = resource_path[1:]

    full_url_path = f"https://api.boomi.com/api/rest/v1/{ACCOUNT_ID}/{resource_path}"

    headers_dict = buildHeadersObject(api_credentials, custom_headers)

    post_response = requests.post(url=full_url_path, data=request_body, headers=headers_dict, auth=(api_credentials['API_USERNAME'], api_credentials['ACCESS_TOKEN']))


    return post_response

# %% [markdown]
# ## Build Query Body - buildQueryBody

# %%
def buildQueryBody(query_params: dict, query_operator: str = "and") -> str:
    '''
    Builds a nested query body for use in a POST query

    Parameters
    ----------
    query_params : dict
        argument:property pairs to use in the query body
    query_operator : str, optional
        query relationship operator, either "and" or "or", by default "and"
 

    Returns
    -------
    str
        The query body as a string
    '''

    nested_expr = []

    for query_prop, query_arg in query_params.items():
        if not isinstance(query_arg, type([])):
            query_arg = [query_arg]

        query_expr = {"argument" : query_arg,
        "operator":"EQUALS",
        "property":query_prop}         
        
        nested_expr.append(query_expr)


    return json.dumps({
        "QueryFilter": {
            "expression": {
                "operator": query_operator,
                "nestedExpression": nested_expr
            }
        }
    })

# %%
def build_query_body(*query_groups: dict, query_operator: str = "and") -> str:
    """
    Builds a nested query body for use in a POST query

    Parameters
    ----------
    query_groups : dict
        argument:property pairs to use in the query body
    query_operator : str, optional
        query relationship operator, either "and" or "or", by default "and"

    Returns
    -------
    str
        The query body as a string
    """

    nested_expr = []

    for query_group in query_groups:
        query_expr = {
            "argument": query_group.get("argument", []),
            "operator": query_group.get("operator", "EQUALS"),
            "property": query_group.get("property", "")
        }
        nested_expr.append(query_expr)

    
    if len(nested_expr) == 1:
        return json.dumps({
            "QueryFilter": {
                "expression": nested_expr[0]
            }
        })
    
    return json.dumps({
        "QueryFilter": {
            "expression": {
                "operator": query_operator,
                "nestedExpression": nested_expr
            }
        }
    })

# %%
r = build_query_body(
    {"argument": ["YL"], "property": "name"},
    query_operator="and")


print(r)
# Out:
# [{'argument': ['YL'], 'operator': 'EQUALS', 'property': 'name'}]
# {"QueryFilter": {"expression": {"argument": ["YL"], "operator": "EQUALS", "property": "name"}}}

# %%
buildQueryBody({"name":"and", "id":"1234"})
# Out:
# '{"QueryFilter": {"expression": {"operator": "and", "nestedExpression": [{"argument": ["and"], "operator": "EQUALS", "property": "name"}, {"argument": ["1234"], "operator": "EQUALS", "property": "id"}]}}}'

# %% [markdown]
# ## Folder Traversal

# %%
def traverseSubfolders(parentFolderName: str) -> pd.DataFrame:

    folderStructure = pd.DataFrame(columns=["folderName", "folderId", "parentFolderName", "parentFolderId", "parsedFlag"])

# %% [markdown]
# # Tests

# %%
folder_query_body = buildQueryBody({"name":["IAM Integrations"]})

# %%
folder_query = postRequestJSON(resource_path="Folder/query", request_body=folder_query_body)

# %%
type(folder_query)
# Out:
# requests.models.Response

# %%
folder_query = postRequestJSON(resource_path="Folder/query", request_body=folder_query_body)
folder_query.reason
# Out:
# 'OK'

# %%
folder_query.json()
# Out:
# {'@type': 'QueryResult',
#  'result': [{'@type': 'Folder',
#    'id': 'Rjo2MTc3MTY2',
#    'name': 'IAM Integrations',
#    'fullPath': 'YL/IAM Integrations',
#    'deleted': False,
#    'parentId': 'RjoxMjA2MzIw',
#    'parentName': 'YL'}],
#  'numberOfResults': 1}

# %%
sub_folder_query_body = buildQueryBody({"parentId":["RjoxMjA2MzIw"]})
sub_folder_query = postRequestJSON(resource_path="Folder/query", request_body=sub_folder_query_body)
sub_folder_query.reason
# Out:
# 'Bad Request'

# %%
sub_folder_query.json()
# Out:
# {'@type': 'QueryResult',
#  'result': [{'@type': 'Folder',
#    'id': 'Rjo2MTYzNDEz',
#    'name': 'Job Code Manager',
#    'fullPath': 'YL/IAM Integrations/Job Code Manager',
#    'deleted': False,
#    'parentId': 'Rjo2MTc3MTY2',
#    'parentName': 'IAM Integrations'},
#   {'@type': 'Folder',
#    'id': 'Rjo2MTc3MjU5',
#    'name': '#Common',
#    'fullPath': 'YL/IAM Integrations/#Common',
#    'deleted': False,
#    'parentId': 'Rjo2MTc3MTY2',
#    'parentName': 'IAM Integrations'},
#   {'@type': 'Folder',
#    'id': 'Rjo2MjM0MjAx',
#    'name': 'User Account Manager',
#    'fullPath': 'YL/IAM Integrations/User Account Manager',
#    'deleted': False,
#    'parentId': 'Rjo2MTc3MTY2',
#    'parentName': 'IAM Integrations'},
#   {'@type': 'Folder',
#    'id': 'Rjo2NjQ0NzYy',
#    'name': 'Candidate Change to YL API',
#    'fullPath': 'YL/IAM Integrations/Candidate Change to YL API',
#    'deleted': False,
#    'parentId': 'Rjo2MTc3MTY2',
#    'parentName': 'IAM Integrations'},
#   {'@type': 'Folder',
#    'id': 'Rjo2ODYwODg0',
#    'name': 'Mission Unit Manager',
#    'fullPath': 'YL/IAM Integrations/Mission Unit Manager',
#    'deleted': True,
#    'parentId': 'Rjo2MTc3MTY2',
#    'parentName': 'IAM Integrations'},
#   {'@type': 'Folder',
#    'id': 'Rjo2ODgwNzk0',
#    'name': 'Mission Unit and Territory Manager',
#    'fullPath': 'YL/IAM Integrations/Mission Unit and Territory Manager',
#    'deleted': False,
#    'parentId': 'Rjo2MTc3MTY2',
#    'parentName': 'IAM Integrations'},
#   {'@type': 'Folder',
#    'id': 'Rjo2OTQ1Nzg1',
#    'name': 'Responsible Party Manager',
#    'fullPath': 'YL/IAM Integrations/Responsible Party Manager',
#    'deleted': False,
#    'parentId': 'Rjo2MTc3MTY2',
#    'parentName': 'IAM Integrations'}],
#  'numberOfResults': 7}

# %%
component_query_body = buildQueryBody({"folderId":"Rjo2MTYzNDEz"})
component_query_body
# Out:
# '{"QueryFilter": {"expression": {"operator": "and", "nestedExpression": [{"argument": ["Rjo2MTYzNDEz"], "operator": "EQUALS", "property": "folderId"}]}}}'

# %%
component_query = postRequestJSON(resource_path="ComponentMetadata/query", request_body=component_query_body)
component_query.reason
# Out:
# 'OK'

# %%
component_query.json()
# Out:
# {'@type': 'QueryResult',
#  'queryToken': '...',
#  'result': [{'@type': 'ComponentMetadata',
#    'componentId': '027a8591-1ff2-4d49-b1fc-acfb1f73e536',
#    'version': 1,
#    'name': 'EFFECTIVE Workday Get_Job_Profiles EXECUTE Request',
#    'type': 'profile.xml',
#    'createdDate': '2023-09-21T17:48:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-21T17:48:02Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'copiedFromComponentId': '355349aa-5cc9-4107-8bba-a036f339eba7',
#    'copiedFromComponentVersion': 2,
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '027a8591-1ff2-4d49-b1fc-acfb1f73e536',
#    'version': 2,
#    'name': 'EFFECTIVE Workday Get_Job_Profiles EXECUTE Request',
#    'type': 'profile.xml',
#    'createdDate': '2023-09-21T17:48:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-21T17:50:20Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '027a8591-1ff2-4d49-b1fc-acfb1f73e536',
#    'version': 3,
#    'name': 'EFFECTIVE Workday Get_Job_Profiles EXECUTE Request',
#    'type': 'profile.xml',
#    'createdDate': '2023-09-21T17:48:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-21T18:07:57Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': True,
#    'currentVersion': True,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '037380cf-93ab-4813-8217-f6130479beea',
#    'version': 1,
#    'name': '[Workday -> YLGlobal] JobCode',
#    'type': 'transform.map',
#    'createdDate': '2023-09-19T15:50:41Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-19T15:50:41Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '037380cf-93ab-4813-8217-f6130479beea',
#    'version': 2,
#    'name': '[Workday -> YLGlobal] JobCode',
#    'type': 'transform.map',
#    'createdDate': '2023-09-19T15:50:41Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-19T20:49:17Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '037380cf-93ab-4813-8217-f6130479beea',
#    'version': 3,
#    'name': '[Workday -> YLGlobal] Update dbo.JobCode',
#    'type': 'transform.map',
#    'createdDate': '2023-09-19T15:50:41Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-21T18:11:15Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '037380cf-93ab-4813-8217-f6130479beea',
#    'version': 4,
#    'name': '[Cononical-> YLGlobal] Update dbo.JobCode',
#    'type': 'transform.map',
#    'createdDate': '2023-09-19T15:50:41Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-25T16:27:39Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '037380cf-93ab-4813-8217-f6130479beea',
#    'version': 5,
#    'name': '[Canonical-> YLGlobal] Update dbo.JobCode',
#    'type': 'transform.map',
#    'createdDate': '2023-09-19T15:50:41Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-28T17:52:30Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '037380cf-93ab-4813-8217-f6130479beea',
#    'version': 6,
#    'name': '[Canonical-> YLGlobal] Update dbo.JobCode',
#    'type': 'transform.map',
#    'createdDate': '2023-09-19T15:50:41Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-10-06T14:42:46Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': True,
#    'currentVersion': True,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 1,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T20:32:02Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 2,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T20:32:55Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 3,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T20:51:57Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 4,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T20:52:23Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 5,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T21:02:03Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 6,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T21:02:35Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 7,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T21:03:21Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 8,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T21:03:31Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 9,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T21:04:31Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 10,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T21:34:44Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 11,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T22:37:55Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 12,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T22:44:38Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 13,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T22:48:20Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 14,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T22:59:48Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 15,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T23:01:07Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 16,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T23:01:33Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 17,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-22T23:01:43Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 18,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-25T16:25:33Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 19,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-25T21:06:22Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 20,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-26T18:52:27Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 21,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-26T19:13:43Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 22,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-26T19:17:17Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 23,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-28T21:51:54Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 24,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-29T15:51:26Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 25,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-29T15:52:51Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 26,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-29T15:54:02Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 27,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-29T16:00:07Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 28,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-10-03T15:23:22Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '05f2525a-f3a1-44d4-9c7f-19d39d81c318',
#    'version': 29,
#    'name': '[sub] Query Job Profiles from Workday',
#    'type': 'process',
#    'createdDate': '2023-09-22T20:32:02Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-10-12T14:02:04Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': True,
#    'currentVersion': True,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '0609ba8d-cb4d-4658-a340-b910e22a6be5',
#    'version': 1,
#    'name': 'Get Source System ID DPPs',
#    'type': 'transform.function',
#    'createdDate': '2023-11-28T16:21:16Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-11-28T16:21:16Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '0609ba8d-cb4d-4658-a340-b910e22a6be5',
#    'version': 2,
#    'name': '[JCM] Get Source System ID DPPs',
#    'type': 'transform.function',
#    'createdDate': '2023-11-28T16:21:16Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-12-05T20:18:44Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '0609ba8d-cb4d-4658-a340-b910e22a6be5',
#    'version': 3,
#    'name': '[Job Code Manager] Get Source System ID DPPs',
#    'type': 'transform.function',
#    'createdDate': '2023-11-28T16:21:16Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-04-26T18:52:37Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '0609ba8d-cb4d-4658-a340-b910e22a6be5',
#    'version': 4,
#    'name': '[Job Code Manager] Get Source System ID DPPs',
#    'type': 'transform.function',
#    'createdDate': '2023-11-28T16:21:16Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-05-30T20:50:58Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '0609ba8d-cb4d-4658-a340-b910e22a6be5',
#    'version': 5,
#    'name': '[Job Code Manager] Get Source System ID DPPs',
#    'type': 'transform.function',
#    'createdDate': '2023-11-28T16:21:16Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-04T19:57:04Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '0609ba8d-cb4d-4658-a340-b910e22a6be5',
#    'version': 6,
#    'name': '[Job Code Manager] Get Source System ID DDPs',
#    'type': 'transform.function',
#    'createdDate': '2023-11-28T16:21:16Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-07-10T14:25:51Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': True,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '08b71ec1-0a68-44e5-9269-9389ef7a1353',
#    'version': 1,
#    'name': 'jobProfileName to Company [iStaff]',
#    'type': 'transform.function',
#    'createdDate': '2023-11-17T21:47:49Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-11-17T21:47:49Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '08b71ec1-0a68-44e5-9269-9389ef7a1353',
#    'version': 2,
#    'name': '[JCM] jobProfileName to Company (iStaff = 25)',
#    'type': 'transform.function',
#    'createdDate': '2023-11-17T21:47:49Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-12-05T20:18:42Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '08b71ec1-0a68-44e5-9269-9389ef7a1353',
#    'version': 3,
#    'name': '[JCM] jobProfileName to Company (iStaff = 25)',
#    'type': 'transform.function',
#    'createdDate': '2023-11-17T21:47:49Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-12-21T17:33:55Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '08b71ec1-0a68-44e5-9269-9389ef7a1353',
#    'version': 4,
#    'name': '[JCM] jobProfileName to Company (iStaff = 25)',
#    'type': 'transform.function',
#    'createdDate': '2023-11-17T21:47:49Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-01-05T23:00:16Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '08b71ec1-0a68-44e5-9269-9389ef7a1353',
#    'version': 5,
#    'name': '[Job Code Manager] jobProfileName to Company Number',
#    'type': 'transform.function',
#    'createdDate': '2023-11-17T21:47:49Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-04-26T18:53:03Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '08b71ec1-0a68-44e5-9269-9389ef7a1353',
#    'version': 6,
#    'name': '[Job Code Manager] jobProfileName to Company Number',
#    'type': 'transform.function',
#    'createdDate': '2023-11-17T21:47:49Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-27T23:00:36Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '08b71ec1-0a68-44e5-9269-9389ef7a1353',
#    'version': 7,
#    'name': '[Job Code Manager] jobProfileName to Company Number',
#    'type': 'transform.function',
#    'createdDate': '2023-11-17T21:47:49Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-29T21:30:10Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '08b71ec1-0a68-44e5-9269-9389ef7a1353',
#    'version': 8,
#    'name': '[Job Code Manager] jobProfileName to Company Number, Build Job Code Name',
#    'type': 'transform.function',
#    'createdDate': '2023-11-17T21:47:49Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-29T21:38:10Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '08b71ec1-0a68-44e5-9269-9389ef7a1353',
#    'version': 9,
#    'name': '[Job Code Manager] jobProfileName to Company Number, Build Job Code Name',
#    'type': 'transform.function',
#    'createdDate': '2023-11-17T21:47:49Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-29T22:15:59Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': True,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 1,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-01-09T21:26:10Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 2,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-01-09T21:26:35Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 3,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-01-09T21:32:47Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 4,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-01-09T22:31:38Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 5,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-01-09T22:47:43Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 6,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-01-09T22:51:49Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 7,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-01-09T22:53:32Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 8,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-01-11T18:22:36Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 9,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-01-11T18:41:10Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 10,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-01-11T18:52:01Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 11,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-03-13T15:46:59Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 12,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-05T21:48:50Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 13,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-27T22:44:53Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 14,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-28T20:58:46Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 15,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-28T20:59:03Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 16,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-29T15:48:32Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 17,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-29T16:47:27Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 18,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-29T16:52:15Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 19,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-29T18:19:05Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 20,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-29T19:24:56Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 21,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-29T19:38:57Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 22,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-29T19:39:04Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 23,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-29T19:39:24Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '090cb580-b0c5-4af0-a3d2-dd7c70c96b2e',
#    'version': 24,
#    'name': '[sub] Send New Job Code Notification Emails',
#    'type': 'process',
#    'createdDate': '2024-01-09T21:26:10Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2025-01-07T19:51:42Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': True,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '0a62c9a9-bc75-4866-b1db-e73721ce8943',
#    'version': 1,
#    'name': '[Job Code Manager] Existing Salesforce JCAC Records',
#    'type': 'documentcache',
#    'createdDate': '2024-06-05T21:41:39Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-05T21:41:39Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '0a62c9a9-bc75-4866-b1db-e73721ce8943',
#    'version': 2,
#    'name': '[Job Code Manager] Existing Salesforce JCAC Records',
#    'type': 'documentcache',
#    'createdDate': '2024-06-05T21:41:39Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-05T21:45:22Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': True,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '15115b4a-b72b-47fa-a124-cd0de54bee92',
#    'version': 1,
#    'name': 'Job Code Manager Process Properties',
#    'type': 'processproperty',
#    'createdDate': '2023-10-19T17:42:55Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-10-19T17:42:55Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '15115b4a-b72b-47fa-a124-cd0de54bee92',
#    'version': 2,
#    'name': 'Job Code Manager Process Properties',
#    'type': 'processproperty',
#    'createdDate': '2023-10-19T17:42:55Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-10-20T14:46:20Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '15115b4a-b72b-47fa-a124-cd0de54bee92',
#    'version': 3,
#    'name': 'Job Code Manager Process Properties',
#    'type': 'processproperty',
#    'createdDate': '2023-10-19T17:42:55Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-10-20T14:48:38Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '15115b4a-b72b-47fa-a124-cd0de54bee92',
#    'version': 4,
#    'name': 'Job Code Manager Process Properties',
#    'type': 'processproperty',
#    'createdDate': '2023-10-19T17:42:55Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-12-13T20:40:39Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '15115b4a-b72b-47fa-a124-cd0de54bee92',
#    'version': 5,
#    'name': 'Job Code Manager Process Properties',
#    'type': 'processproperty',
#    'createdDate': '2023-10-19T17:42:55Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-01-02T15:56:27Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '15115b4a-b72b-47fa-a124-cd0de54bee92',
#    'version': 6,
#    'name': 'Job Code Manager Process Properties',
#    'type': 'processproperty',
#    'createdDate': '2023-10-19T17:42:55Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-05-30T19:42:33Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '15115b4a-b72b-47fa-a124-cd0de54bee92',
#    'version': 7,
#    'name': 'Job Code Manager Process Properties',
#    'type': 'processproperty',
#    'createdDate': '2023-10-19T17:42:55Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-06-27T22:40:01Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': True,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '18f971aa-6ee9-4ad2-a8e4-dd460c04933b',
#    'version': 1,
#    'name': '[Conincal-> SF] Upsert JCAC__c',
#    'type': 'transform.map',
#    'createdDate': '2023-09-28T15:37:42Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-28T15:37:42Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '18f971aa-6ee9-4ad2-a8e4-dd460c04933b',
#    'version': 2,
#    'name': '[Conincal-> Salesforce] Upsert JCAC__c',
#    'type': 'transform.map',
#    'createdDate': '2023-09-28T15:37:42Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-28T17:51:19Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '18f971aa-6ee9-4ad2-a8e4-dd460c04933b',
#    'version': 3,
#    'name': '[Canonical-> Salesforce] Upsert JCAC__c',
#    'type': 'transform.map',
#    'createdDate': '2023-09-28T15:37:42Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-09-28T17:52:20Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '18f971aa-6ee9-4ad2-a8e4-dd460c04933b',
#    'version': 4,
#    'name': '[Canonical-> Salesforce] Upsert JCAC__c',
#    'type': 'transform.map',
#    'createdDate': '2023-09-28T15:37:42Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-10-18T22:23:24Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '18f971aa-6ee9-4ad2-a8e4-dd460c04933b',
#    'version': 5,
#    'name': '[Canonical-> Salesforce] Upsert JCAC__c',
#    'type': 'transform.map',
#    'createdDate': '2023-09-28T15:37:42Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-11-17T22:10:20Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '18f971aa-6ee9-4ad2-a8e4-dd460c04933b',
#    'version': 6,
#    'name': '[Canonical-> Salesforce] Upsert JCAC__c',
#    'type': 'transform.map',
#    'createdDate': '2023-09-28T15:37:42Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-11-17T22:12:35Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '18f971aa-6ee9-4ad2-a8e4-dd460c04933b',
#    'version': 7,
#    'name': '[Canonical-> Salesforce] Create JCAC__c',
#    'type': 'transform.map',
#    'createdDate': '2023-09-28T15:37:42Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-11-28T16:48:45Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '18f971aa-6ee9-4ad2-a8e4-dd460c04933b',
#    'version': 8,
#    'name': '[Canonical-> Salesforce] Create JCAC__c',
#    'type': 'transform.map',
#    'createdDate': '2023-09-28T15:37:42Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-11-29T15:41:30Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '18f971aa-6ee9-4ad2-a8e4-dd460c04933b',
#    'version': 9,
#    'name': '[Canonical-> Salesforce] Create JCAC__c',
#    'type': 'transform.map',
#    'createdDate': '2023-09-28T15:37:42Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-11-29T15:43:46Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '18f971aa-6ee9-4ad2-a8e4-dd460c04933b',
#    'version': 10,
#    'name': '[Canonical-> Salesforce] Create JCAC__c',
#    'type': 'transform.map',
#    'createdDate': '2023-09-28T15:37:42Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2023-12-20T10:30:29Z',
#    'modifiedBy': 'hamza.aqeel@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '18f971aa-6ee9-4ad2-a8e4-dd460c04933b',
#    'version': 11,
#    'name': '[Canonical-> Salesforce] Create JCAC__c',
#    'type': 'transform.map',
#    'createdDate': '2023-09-28T15:37:42Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-01-05T21:17:45Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '18f971aa-6ee9-4ad2-a8e4-dd460c04933b',
#    'version': 12,
#    'name': '[Canonical-> Salesforce] Create JCAC__c',
#    'type': 'transform.map',
#    'createdDate': '2023-09-28T15:37:42Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-01-05T21:29:05Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': True,
#    'currentVersion': True,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '236f822d-a49b-4627-a73e-8916077dfd82',
#    'version': 1,
#    'name': '[YLGlobal] Generate JobCodeID UUID',
#    'type': 'transform.map',
#    'createdDate': '2024-01-09T22:16:33Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-01-09T22:16:33Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'},
#   {'@type': 'ComponentMetadata',
#    'componentId': '236f822d-a49b-4627-a73e-8916077dfd82',
#    'version': 2,
#    'name': '[YLGlobal] Generate JobCodeID UUID',
#    'type': 'transform.map',
#    'createdDate': '2024-01-09T22:16:33Z',
#    'createdBy': 'andy.strubhar@argano.com',
#    'modifiedDate': '2024-01-09T22:36:48Z',
#    'modifiedBy': 'andy.strubhar@argano.com',
#    'deleted': False,
#    'currentVersion': False,
#    'folderName': 'Job Code Manager',
#    'folderId': 'Rjo2MTYzNDEz',
#    'branchName': 'main',
#    'branchId': 'QjoyNTU4NQ'}],
#  'numberOfResults': 1198}
